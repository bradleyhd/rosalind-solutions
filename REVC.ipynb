# %%
s = '...'

# %%
t = s[::-1]
o = ''
for c in t:
    if (c == 'A'):
        o += 'T'
    elif (c == 'T'):
        o += 'A'
    elif (c == 'C'):
        o += 'G'
    elif (c == 'G'):
        o += 'C'
print(o)
# Out:
# ...
