# %%
s = '...'
t = 'GGTACTTGG'

# %%
idx = 0
while(True):
    p = s.find(t, idx)
    if(p == -1):
        break
    idx = p + 1
    print (idx),
# Out:
# 114 171 188 195 236 274 309 316 362 406 422 441 482 510 525 532 663 670 793 800 808 824 832 881 888 909 924
